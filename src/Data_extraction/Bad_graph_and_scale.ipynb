# %%
import h5py
import numpy as np
import networkx as nx
import pickle
from joblib import Parallel, delayed
from scipy.stats import entropy
import torch
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.utils import from_networkx

# %%
def bin_to_tick(burst_bin, bin_width_ms=10, tick_ms=0.1):
    """
    Convert burst start bin number to tick.
    
    Parameters:
    - burst_bin: int, the burst start bin index.
    - bin_width_ms: float, duration of each bin in milliseconds (default 10ms).
    - tick_ms: float, duration of one tick in milliseconds (default 0.1ms).
    
    Returns:
    - tick: int, corresponding tick number.
    """
    ticks_per_bin = bin_width_ms / tick_ms
    return int(burst_bin * ticks_per_bin)

# %%
def get_pre_burst_spikes_and_features(h5_path, node_ids, burst_tick, k=20):
    """
    For each node in node_ids, extract last k spikes before burst_tick and compute features.
    Returns a dict: node_id -> {'spikes': np.array[k], **features_dict}
    """
    result = {}
    with h5py.File(h5_path, 'r') as h5:
        for n in node_ids:
            ds = f"Neuron_{n}"
            if ds not in h5:
                arr = np.zeros(k, dtype=float)
                feats = get_spike_features(arr)
            else:
                spikes = np.sort(h5[ds][()]).astype(float)
                idx0 = np.searchsorted(spikes, burst_tick)
                last_k = spikes[max(0, idx0-k):idx0]
                if len(last_k) < k:
                    last_k = np.pad(last_k, (k-len(last_k), 0), 'constant')
                arr = last_k
                feats = get_spike_features(arr)
            entry = {'spikes': arr}
            entry.update(feats)
            result[n] = entry
    return result

def get_non_burst_spikes_and_features(h5_path, node_ids, burst_tick, k=20, gap = 100):
    """
    Extract the last k spike times before burst_tick for each node.
    Returns a dict: node_id -> 1D np.array of length k.
    """
    result = {}
    with h5py.File(h5_path, 'r') as h5:
        for n in node_ids:
            ds = f"Neuron_{n}"
            if ds not in h5:
                arr = np.zeros(k, dtype=float)
                feats = get_spike_features(arr)
            else:
                spikes = np.sort(h5[ds][()]).astype(float)
                idx0 = np.searchsorted(spikes, burst_tick)
                last_k = spikes[max(0, idx0 - k - gap):idx0 - gap]
                if len(last_k) < k:
                    last_k = np.pad(last_k, (k-len(last_k), 0), 'constant')
                arr = last_k
                feats = get_spike_features(arr)
            entry = {'spikes': arr}
            entry.update(feats)
            result[n] = entry
    return result

def get_spike_features(spikes):
    """
    Convert spike times to features.
    Here we simply return the spike times as features.
    """
    # Example feature extraction: normalize and scale
    isis = np.diff(spikes)
    m, s = np.nanmean(isis), np.nanstd(isis)

    return {
       'mean_isi': m,
       'entropy_isi': entropy(isis)       
    }

# assume these helper functions are defined elsewhere in your script:
# - bin_to_tick(burst_bin, bin_width_ms, tick_ms)
# - get_spikes_and_features(h5_path, node_ids, burst_tick, k)
# - get_non_burst_spikes_and_features(h5_path, node_ids, burst_tick, k, gap)

h5_path    = "/DATA/hdhanu/GNN/Burst_Data/tR_1.0--fE_0.98_10000.h5"
pkl_path   = "/DATA/hdhanu/GNN/Graphs_and_Features/Sub_graph/subgraphs_final.pkl"
entries    = pickle.load(open(pkl_path, 'rb'))

# list of summary feature names (must match get_spike_features keys)
feat_names = [
    'mean_isi','entropy_isi'
]

data_list = []
def process_entry(entry):
    originbin  = entry['burstoriginbin']
    burst_tick = bin_to_tick(originbin, bin_width_ms=10, tick_ms=0.1)
    G = entry['subgraph']
    nodes = list(G.nodes())
    edge_index = from_networkx(G).edge_index

    pre_dict = get_pre_burst_spikes_and_features(h5_path, nodes, burst_tick, k=20)
    non_dict = get_non_burst_spikes_and_features(h5_path, nodes, burst_tick, k=20, gap=100)

    # Build feature matrices in node order
    pre_feats = [[pre_dict[n][f] for f in feat_names] for n in nodes]
    non_feats = [[non_dict[n][f] for f in feat_names] for n in nodes]

    pre_data = Data(
        x=torch.tensor(pre_feats, dtype=torch.float),
        edge_index=edge_index,
        y=torch.tensor([1])
    )
    non_data = Data(
        x=torch.tensor(non_feats, dtype=torch.float),
        edge_index=edge_index,
        y=torch.tensor([0])
    )
    return pre_data, non_data

if __name__ == '__main__':
    # Parallelize over all entries using all available cores
    results = Parallel(n_jobs=-1, verbose=10)(
        delayed(process_entry)(entry) for entry in entries
    )

    # Unpack into a single list
    data_list = []
    for pre_data, non_data in results:
        data_list.extend([pre_data, non_data])

    # Save processed dataset
    torch.save(data_list, '/DATA/hdhanu/GNN/Manual_check/processed_data.pt')

    # Wrap in a DataLoader for training
    loader = DataLoader(data_list, batch_size=32, shuffle=True)

    # Verify
    for batch in loader:
        print(batch.x.shape, batch.edge_index.shape, batch.y.shape)
        break
# Out:
# Processed Burst 6135 with 107 nodes.
# Processed Burst 4434 with 132 nodes.
# Processed Burst 5132 with 122 nodes.
# Processed Burst 7521 with 108 nodes.
# Processed Burst 7021 with 145 nodes.
# Processed Burst 2586 with 134 nodes.
# Processed Burst 8089 with 145 nodes.
# Processed Burst 3821 with 140 nodes.
# Processed Burst 1073 with 132 nodes.
# Processed Burst 2432 with 122 nodes.
# Processed Burst 2318 with 145 nodes.
# Processed Burst 8173 with 107 nodes.
# Processed Burst 6014 with 107 nodes.
# Processed Burst 170 with 133 nodes.
# Processed Burst 5114 with 122 nodes.
# Processed Burst 8977 with 130 nodes.
# Processed Burst 5422 with 108 nodes.
# Processed Burst 4959 with 97 nodes.
# Processed Burst 5547 with 141 nodes.
# Processed Burst 6944 with 108 nodes.
# Processed Burst 532 with 128 nodes.
# Processed Burst 6051 with 108 nodes.
# Processed Burst 3103 with 141 nodes.
# Processed Burst 1645 with 138 nodes.
# Processed Burst 7093 with 99 nodes.
# Processed Burst 481 with 133 nodes.
# Processed Burst 3084 with 132 nodes.
# Processed Burst 5801 with 145 nodes.
# Processed Burst 1841 with 138 nodes.
# Processed Burst 3062 with 108 nodes.
# Processed Burst 2590 with 107 nodes.
# Processed Burst 6104 with 108 nodes.
# Processed Burst 4139 with 107 nodes.
# Processed Burst 4749 with 107 nodes.
# Processed Burst 3158 with 107 nodes.
# Processed Burst 4748 with 99 nodes.
# Processed Burst 5181 with 99 nodes.
# Processed Burst 6316 with 145 nodes.
# Processed Burst 2666 with 138 nodes.
# Processed Burst 729 with 139 nodes.
# Processed Burst 7604 with 141 nodes.
# Processed Burst 5938 with 111 nodes.
# Processed Burst 3178 with 141 nodes.
# Processed Burst 2687 with 107 nodes.
# Processed Burst 5897 with 107 nodes.
# Processed Burst 7174 with 111 nodes.
# Processed Burst 300 with 98 nodes.
# Processed Burst 6423 with 134 nodes.
# Processed Burst 1196 with 99 nodes.
# Processed Burst 6264 with 129 nodes.
# Processed Burst 5059 with 141 nodes.
# Processed Burst 8865 with 107 nodes.
# Processed Burst 2637 with 108 nodes.
# Processed Burst 1639 with 137 nodes.
# Processed Burst 3311 with 107 nodes.
# Processed Burst 1607 with 141 nodes.
# Processed Burst 5209 with 145 nodes.
# Processed Burst 5354 with 123 nodes.
# Processed Burst 5279 with 107 nodes.
# Processed Burst 6101 with 107 nodes.
# Processed Burst 294 with 122 nodes.
# Processed Burst 8014 with 107 nodes.
# Processed Burst 6030 with 141 nodes.
# Processed Burst 3086 with 108 nodes.
# Processed Burst 1222 with 98 nodes.
# Processed Burst 8309 with 111 nodes.
# Processed Burst 8899 with 111 nodes.
# Processed Burst 2404 with 98 nodes.
# Processed Burst 8534 with 107 nodes.
# Processed Burst 2034 with 107 nodes.
# Processed Burst 6015 with 111 nodes.
# Processed Burst 938 with 135 nodes.
# Processed Burst 6806 with 141 nodes.
# Processed Burst 2091 with 122 nodes.
# Processed Burst 1315 with 97 nodes.
# Processed Burst 5126 with 107 nodes.
# Processed Burst 4388 with 127 nodes.
# Processed Burst 602 with 133 nodes.
# Processed Burst 344 with 138 nodes.
# Processed Burst 3545 with 141 nodes.
# Processed Burst 6794 with 108 nodes.
# Processed Burst 8327 with 107 nodes.
# Processed Burst 8304 with 108 nodes.
# Processed Burst 5862 with 111 nodes.
# Processed Burst 8175 with 145 nodes.
# Processed Burst 263 with 131 nodes.
# Processed Burst 2075 with 98 nodes.
# Processed Burst 5125 with 138 nodes.
# Processed Burst 7331 with 122 nodes.
# Processed Burst 8550 with 99 nodes.
# Processed Burst 7531 with 111 nodes.
# Processed Burst 64 with 95 nodes.
# Processed Burst 7811 with 107 nodes.
# Processed Burst 3841 with 108 nodes.
# Processed Burst 7367 with 145 nodes.
# Processed Burst 8367 with 107 nodes.
# Processed Burst 3655 with 138 nodes.
# Processed Burst 4115 with 108 nodes.
# Processed Burst 7640 with 145 nodes.
# Processed Burst 1211 with 99 nodes.
# Processed Burst 574 with 126 nodes.
# Processed Burst 2105 with 141 nodes.
# Processed Burst 2625 with 122 nodes.
# Processed Burst 8990 with 141 nodes.
# Processed Burst 8752 with 107 nodes.
# Processed Burst 1199 with 99 nodes.
# Processed Burst 8276 with 111 nodes.
# Processed Burst 8234 with 107 nodes.
# Processed Burst 2570 with 129 nodes.
# Processed Burst 2896 with 121 nodes.
# Processed Burst 5043 with 111 nodes.
# Processed Burst 5595 with 122 nodes.
# Processed Burst 6343 with 107 nodes.
# Processed Burst 5724 with 134 nodes.
# Processed Burst 3719 with 141 nodes.
# Processed Burst 3826 with 138 nodes.
# Processed Burst 7463 with 111 nodes.
# Processed Burst 4892 with 108 nodes.
# Processed Burst 9088 with 111 nodes.
# Processed Burst 5381 with 108 nodes.
# Processed Burst 4951 with 141 nodes.
# Processed Burst 8429 with 133 nodes.
# Processed Burst 4077 with 108 nodes.
# Processed Burst 3391 with 107 nodes.
# Processed Burst 7113 with 111 nodes.
# Processed Burst 7406 with 122 nodes.
# Processed Burst 402 with 133 nodes.
# Processed Burst 3997 with 107 nodes.
# Processed Burst 4549 with 111 nodes.
# Processed Burst 2681 with 141 nodes.
# Processed Burst 7890 with 108 nodes.
# Processed Burst 5160 with 99 nodes.
# Processed Burst 7121 with 99 nodes.
# Processed Burst 7103 with 134 nodes.
# Processed Burst 5827 with 107 nodes.
# Processed Burst 2171 with 141 nodes.
# Processed Burst 7072 with 107 nodes.
# Processed Burst 2210 with 145 nodes.
# Processed Burst 5652 with 107 nodes.
# Processed Burst 8988 with 111 nodes.
# Processed Burst 1566 with 111 nodes.
# Processed Burst 3212 with 108 nodes.
# Processed Burst 8462 with 141 nodes.
# Processed Burst 3292 with 138 nodes.
# Processed Burst 3857 with 108 nodes.
# Processed Burst 1191 with 98 nodes.
# Processed Burst 5838 with 107 nodes.
# Processed Burst 2904 with 141 nodes.
# Processed Burst 4681 with 107 nodes.
# Processed Burst 5988 with 107 nodes.
# Processed Burst 7016 with 111 nodes.
# Processed Burst 3724 with 145 nodes.
# Processed Burst 1824 with 97 nodes.
# Processed Burst 8476 with 145 nodes.
# Processed Burst 5003 with 145 nodes.
# Processed Burst 2542 with 108 nodes.
# Processed Burst 4294 with 107 nodes.
# Processed Burst 1930 with 108 nodes.
# Processed Burst 654 with 132 nodes.
# Processed Burst 7469 with 141 nodes.
# Processed Burst 2934 with 111 nodes.
# Processed Burst 726 with 111 nodes.
# Processed Burst 4885 with 107 nodes.
# Processed Burst 28 with 131 nodes.
# Processed Burst 7960 with 145 nodes.
# Processed Burst 7722 with 111 nodes.
# Processed Burst 5683 with 145 nodes.
# Processed Burst 8834 with 99 nodes.
# Processed Burst 2323 with 98 nodes.
# Processed Burst 4254 with 108 nodes.
# Processed Burst 6225 with 145 nodes.
# Processed Burst 2170 with 141 nodes.
# Processed Burst 3751 with 145 nodes.
# Processed Burst 3459 with 122 nodes.
# Processed Burst 6908 with 107 nodes.
# Processed Burst 5294 with 141 nodes.
# Processed Burst 1348 with 138 nodes.
# Processed Burst 907 with 123 nodes.
# Processed Burst 5672 with 134 nodes.
# Processed Burst 5799 with 141 nodes.
# Processed Burst 4709 with 141 nodes.
# Processed Burst 3583 with 132 nodes.
# Processed Burst 4251 with 111 nodes.
# Processed Burst 512 with 99 nodes.
# Processed Burst 7605 with 99 nodes.
# Processed Burst 8602 with 145 nodes.
# Processed Burst 4814 with 98 nodes.
# Processed Burst 2104 with 134 nodes.
# Processed Burst 8885 with 107 nodes.
# Processed Burst 2976 with 99 nodes.
# Processed Burst 4240 with 97 nodes.
# Processed Burst 2480 with 141 nodes.
# Processed Burst 6266 with 107 nodes.
# Processed Burst 6075 with 145 nodes.
# Processed Burst 778 with 122 nodes.
# Processed Burst 6 with 105 nodes.
# Processed Burst 4350 with 108 nodes.
# Processed Burst 2616 with 135 nodes.
# Processed Burst 2251 with 107 nodes.
# Processed Burst 7850 with 107 nodes.
# Processed Burst 421 with 133 nodes.
# Processed Burst 8953 with 99 nodes.
# Processed Burst 3988 with 99 nodes.
# Processed Burst 2387 with 122 nodes.
# Processed Burst 4535 with 97 nodes.
# Processed Burst 6270 with 107 nodes.
# Processed Burst 8964 with 111 nodes.
# Processed Burst 2839 with 99 nodes.
# Processed Burst 815 with 132 nodes.
# Processed Burst 3059 with 107 nodes.
# Processed Burst 1166 with 98 nodes.
# Processed Burst 4580 with 145 nodes.
# Processed Burst 4067 with 111 nodes.
# Processed Burst 1501 with 98 nodes.
# Processed Burst 8761 with 122 nodes.
# Processed Burst 2041 with 141 nodes.
# Processed Burst 1523 with 133 nodes.
# Processed Burst 3593 with 97 nodes.
# Processed Burst 7754 with 121 nodes.
# Processed Burst 8286 with 108 nodes.
# Processed Burst 1731 with 145 nodes.
# Processed Burst 6338 with 141 nodes.
# Processed Burst 931 with 108 nodes.
# Processed Burst 8969 with 141 nodes.
# Processed Burst 1555 with 141 nodes.
# Processed Burst 4579 with 107 nodes.
# Processed Burst 6118 with 122 nodes.
# Processed Burst 8903 with 107 nodes.
# Processed Burst 3592 with 108 nodes.
# Processed Burst 5723 with 141 nodes.
# Processed Burst 5664 with 145 nodes.
# Processed Burst 7383 with 141 nodes.
# Processed Burst 3334 with 122 nodes.
# Processed Burst 7740 with 107 nodes.
# Processed Burst 5798 with 141 nodes.
# Processed Burst 8576 with 121 nodes.
# Processed Burst 6407 with 108 nodes.
# Processed Burst 7168 with 108 nodes.
# Processed Burst 2328 with 107 nodes.
# Processed Burst 8937 with 145 nodes.
# Processed Burst 3026 with 130 nodes.
# Processed Burst 3319 with 145 nodes.
# Processed Burst 2412 with 107 nodes.
# Processed Burst 2246 with 141 nodes.
# Processed Burst 3430 with 141 nodes.
# Processed Burst 6837 with 134 nodes.
# Processed Burst 4802 with 107 nodes.
# Processed Burst 6477 with 111 nodes.
# Processed Burst 1082 with 107 nodes.
# Processed Burst 1134 with 99 nodes.
# Processed Burst 3823 with 107 nodes.
# Processed Burst 6243 with 145 nodes.
# Processed Burst 343 with 145 nodes.
# Processed Burst 1232 with 138 nodes.
# Processed Burst 2905 with 107 nodes.
# Processed Burst 141 with 138 nodes.
# Processed Burst 5033 with 144 nodes.
# Processed Burst 7073 with 145 nodes.
# Processed Burst 6486 with 138 nodes.
# Processed Burst 4835 with 141 nodes.
# Processed Burst 8250 with 107 nodes.
# Processed Burst 7493 with 145 nodes.
# Processed Burst 4389 with 140 nodes.
# Processed Burst 4550 with 97 nodes.
# Processed Burst 5943 with 108 nodes.
# Processed Burst 4352 with 107 nodes.
# Processed Burst 8933 with 107 nodes.
# Processed Burst 4208 with 97 nodes.
# Processed Burst 1981 with 107 nodes.
# Processed Burst 7134 with 107 nodes.
# Processed Burst 6657 with 107 nodes.
# Processed Burst 1779 with 107 nodes.
# Processed Burst 2213 with 130 nodes.
# Processed Burst 2037 with 141 nodes.
# Processed Burst 11 with 95 nodes.
# Processed Burst 5881 with 108 nodes.
# Processed Burst 2163 with 99 nodes.
# Processed Burst 6235 with 107 nodes.
# Processed Burst 2741 with 108 nodes.
# Processed Burst 7251 with 107 nodes.
# Processed Burst 4593 with 122 nodes.
# Processed Burst 287 with 98 nodes.
# Processed Burst 4794 with 122 nodes.
# Processed Burst 767 with 139 nodes.
# Processed Burst 7679 with 141 nodes.
# Processed Burst 9106 with 108 nodes.
# Processed Burst 4313 with 108 nodes.
# Processed Burst 4907 with 99 nodes.
# Processed Burst 9038 with 111 nodes.
# Processed Burst 1634 with 98 nodes.
# Processed Burst 6909 with 108 nodes.
# Processed Burst 7499 with 145 nodes.
# Processed Burst 1880 with 122 nodes.
# Processed Burst 1508 with 98 nodes.
# Processed Burst 4297 with 97 nodes.
# Processed Burst 207 with 141 nodes.
# Processed Burst 616 with 97 nodes.
# Processed Burst 8217 with 99 nodes.
# Processed Burst 5052 with 121 nodes.
# Processed Burst 8165 with 141 nodes.
# Processed Burst 555 with 122 nodes.
# Processed Burst 8225 with 107 nodes.
# Processed Burst 2555 with 138 nodes.
# Processed Burst 8407 with 145 nodes.
# Processed Burst 1370 with 137 nodes.
# Processed Burst 6278 with 108 nodes.
# Processed Burst 5803 with 141 nodes.
# Processed Burst 3298 with 129 nodes.
# Processed Burst 1133 with 99 nodes.
# Processed Burst 6715 with 107 nodes.
# Processed Burst 5246 with 111 nodes.
# Processed Burst 5090 with 111 nodes.
# Processed Burst 8139 with 111 nodes.
# Processed Burst 8546 with 111 nodes.
# Processed Burst 5250 with 121 nodes.
# Processed Burst 5139 with 141 nodes.
# Processed Burst 4523 with 108 nodes.
# Processed Burst 6991 with 145 nodes.
# Processed Burst 1207 with 107 nodes.
# Processed Burst 6591 with 99 nodes.
# Processed Burst 3726 with 99 nodes.
# Processed Burst 2694 with 98 nodes.
# Processed Burst 313 with 138 nodes.
# Processed Burst 1797 with 138 nodes.
# Processed Burst 8445 with 107 nodes.
# Processed Burst 4955 with 108 nodes.
# Processed Burst 6950 with 107 nodes.
# Processed Burst 8701 with 111 nodes.
# Processed Burst 5255 with 107 nodes.
# Processed Burst 1444 with 132 nodes.
# Processed Burst 3729 with 134 nodes.
# Processed Burst 415 with 131 nodes.
# Processed Burst 3739 with 121 nodes.
# Processed Burst 571 with 138 nodes.
# Processed Burst 4243 with 145 nodes.
# Processed Burst 5968 with 107 nodes.
# Processed Burst 5504 with 141 nodes.
# Processed Burst 4046 with 107 nodes.
# Processed Burst 5743 with 107 nodes.
# Processed Burst 6345 with 108 nodes.
# Processed Burst 4298 with 99 nodes.
# Processed Burst 5024 with 107 nodes.
# Processed Burst 8704 with 141 nodes.
# Processed Burst 5060 with 108 nodes.
# Processed Burst 2534 with 107 nodes.
# Processed Burst 2675 with 108 nodes.
# Processed Burst 1492 with 107 nodes.
# Processed Burst 674 with 97 nodes.
# Processed Burst 1627 with 140 nodes.
# Processed Burst 7851 with 141 nodes.
# Processed Burst 3296 with 139 nodes.
# Processed Burst 1573 with 141 nodes.
# Processed Burst 5269 with 145 nodes.
# Processed Burst 8668 with 145 nodes.
# Processed Burst 7193 with 107 nodes.
# Processed Burst 4236 with 97 nodes.
# Processed Burst 6556 with 108 nodes.
# Processed Burst 6916 with 107 nodes.
# Processed Burst 3551 with 99 nodes.
# Processed Burst 3914 with 145 nodes.
# Processed Burst 6374 with 107 nodes.
# Processed Burst 7468 with 134 nodes.
# Processed Burst 5390 with 107 nodes.
# Processed Burst 7637 with 107 nodes.
# Processed Burst 687 with 132 nodes.
# Processed Burst 5706 with 111 nodes.
# Processed Burst 949 with 121 nodes.
# Processed Burst 9069 with 141 nodes.
# Processed Burst 5646 with 141 nodes.
# Processed Burst 6140 with 134 nodes.
# Processed Burst 9162 with 111 nodes.
# Processed Burst 1066 with 99 nodes.
# Processed Burst 8099 with 107 nodes.
# Processed Burst 5397 with 111 nodes.
# Processed Burst 603 with 145 nodes.
# Processed Burst 7340 with 107 nodes.
# Processed Burst 8698 with 107 nodes.
# Processed Burst 8636 with 108 nodes.
# Processed Burst 8203 with 108 nodes.
# Processed Burst 1908 with 135 nodes.
# Processed Burst 3446 with 108 nodes.
# Processed Burst 7593 with 140 nodes.
# Processed Burst 8521 with 145 nodes.
# Processed Burst 1375 with 98 nodes.
# Processed Burst 6113 with 107 nodes.
# Processed Burst 6827 with 108 nodes.
# Processed Burst 7341 with 111 nodes.
# Processed Burst 8472 with 108 nodes.
# Processed Burst 4430 with 129 nodes.
# Processed Burst 6036 with 108 nodes.
# Processed Burst 2032 with 98 nodes.
# Processed Burst 4348 with 145 nodes.
# Processed Burst 1077 with 132 nodes.
# Processed Burst 2952 with 138 nodes.
# Processed Burst 4029 with 141 nodes.
# Processed Burst 7304 with 108 nodes.
# Processed Burst 2433 with 108 nodes.
# Processed Burst 7503 with 107 nodes.
# Processed Burst 4635 with 107 nodes.
# Processed Burst 8260 with 138 nodes.
# Processed Burst 8603 with 145 nodes.
# Processed Burst 525 with 131 nodes.
# Processed Burst 2964 with 107 nodes.
# Processed Burst 4626 with 97 nodes.
# Processed Burst 305 with 138 nodes.
# Processed Burst 4763 with 108 nodes.
# Processed Burst 7932 with 99 nodes.
# Processed Burst 2601 with 141 nodes.
# Processed Burst 1106 with 98 nodes.
# Processed Burst 1693 with 107 nodes.
# Processed Burst 8314 with 111 nodes.
# Processed Burst 1277 with 107 nodes.
# Processed Burst 4054 with 111 nodes.
# Processed Burst 6643 with 108 nodes.
# Processed Burst 4750 with 111 nodes.
# Processed Burst 8168 with 141 nodes.
# Processed Burst 4069 with 98 nodes.
# Processed Burst 1621 with 141 nodes.
# Processed Burst 5005 with 107 nodes.
# Processed Burst 6706 with 141 nodes.
# Processed Burst 2691 with 97 nodes.
# Processed Burst 4036 with 141 nodes.
# Processed Burst 3529 with 99 nodes.
# Processed Burst 5323 with 145 nodes.
# Processed Burst 2982 with 108 nodes.
# Processed Burst 996 with 97 nodes.
# Processed Burst 7735 with 107 nodes.
# Processed Burst 1336 with 108 nodes.
# Processed Burst 3218 with 97 nodes.
# Processed Burst 2370 with 144 nodes.
# Processed Burst 7010 with 107 nodes.
# Processed Burst 4245 with 135 nodes.
# Processed Burst 8999 with 107 nodes.
# Processed Burst 5772 with 145 nodes.
# Processed Burst 2365 with 137 nodes.
# Processed Burst 6310 with 138 nodes.
# Processed Burst 7050 with 107 nodes.
# Processed Burst 8657 with 111 nodes.
# Processed Burst 4247 with 139 nodes.
# Processed Burst 2252 with 138 nodes.
# Processed Burst 1026 with 123 nodes.
# Processed Burst 2659 with 122 nodes.
# Processed Burst 7981 with 108 nodes.
# Processed Burst 1432 with 143 nodes.
# Processed Burst 620 with 130 nodes.
# Processed Burst 7523 with 107 nodes.
# Processed Burst 492 with 97 nodes.
# Processed Burst 6784 with 108 nodes.
# Processed Burst 854 with 137 nodes.
# Processed Burst 1454 with 111 nodes.
# Processed Burst 6144 with 138 nodes.
# Processed Burst 8784 with 108 nodes.
# Processed Burst 670 with 123 nodes.
# Processed Burst 3130 with 108 nodes.
# Processed Burst 2689 with 108 nodes.
# Processed Burst 4283 with 99 nodes.
# Processed Burst 6785 with 107 nodes.
# Processed Burst 1000 with 137 nodes.
# Processed Burst 8254 with 107 nodes.
# Processed Burst 4569 with 138 nodes.
# Processed Burst 667 with 138 nodes.
# Processed Burst 7582 with 108 nodes.
# Processed Burst 8923 with 111 nodes.
# Processed Burst 1953 with 108 nodes.
# Processed Burst 1317 with 98 nodes.
# Processed Burst 103 with 125 nodes.
# Processed Burst 4906 with 107 nodes.
# Processed Burst 2215 with 132 nodes.
# Processed Burst 2327 with 132 nodes.
# Processed Burst 4584 with 107 nodes.
# Processed Burst 7743 with 107 nodes.
# Processed Burst 1238 with 122 nodes.
# Processed Burst 7283 with 107 nodes.
# Processed Burst 6389 with 145 nodes.
# Processed Burst 7384 with 107 nodes.
# Processed Burst 6142 with 99 nodes.
# Processed Burst 7293 with 108 nodes.
# Processed Burst 5807 with 141 nodes.
# Processed Burst 1111 with 107 nodes.
# Processed Burst 7984 with 111 nodes.
# Processed Burst 6312 with 145 nodes.
# Processed Burst 5162 with 111 nodes.
# Processed Burst 7366 with 107 nodes.
# Processed Burst 3591 with 108 nodes.
# Processed Burst 1449 with 134 nodes.
# Processed Burst 1696 with 99 nodes.
# Processed Burst 3100 with 144 nodes.
# Processed Burst 4943 with 107 nodes.
# Processed Burst 1005 with 138 nodes.
# Processed Burst 8873 with 130 nodes.
# Processed Burst 1773 with 98 nodes.
# Processed Burst 2763 with 121 nodes.
# Processed Burst 6555 with 108 nodes.
# Processed Burst 5409 with 99 nodes.
# Processed Burst 598 with 126 nodes.
# Processed Burst 271 with 121 nodes.
# Processed Burst 7759 with 107 nodes.
# Processed Burst 3535 with 141 nodes.
# Processed Burst 9012 with 111 nodes.
# Processed Burst 7862 with 111 nodes.
# Processed Burst 9096 with 107 nodes.
# Processed Burst 4663 with 107 nodes.
# Processed Burst 3737 with 97 nodes.
# Processed Burst 3962 with 97 nodes.
# Processed Burst 7687 with 108 nodes.
# Processed Burst 8482 with 145 nodes.
# Processed Burst 1946 with 111 nodes.
# Processed Burst 3207 with 108 nodes.
# Processed Burst 499 with 127 nodes.
# Processed Burst 779 with 98 nodes.
# Processed Burst 298 with 102 nodes.
# Processed Burst 4797 with 108 nodes.
# Processed Burst 3624 with 107 nodes.
# Processed Burst 2668 with 98 nodes.
# Processed Burst 5994 with 141 nodes.
# Processed Burst 2566 with 138 nodes.
# Processed Burst 8427 with 111 nodes.
# Processed Burst 4529 with 111 nodes.
# Processed Burst 3842 with 111 nodes.
# Processed Burst 7906 with 111 nodes.
# Processed Burst 190 with 95 nodes.
# Processed Burst 7396 with 108 nodes.
# Processed Burst 7571 with 99 nodes.
# Processed Burst 5030 with 99 nodes.
# Processed Burst 7166 with 134 nodes.
# Processed Burst 7596 with 108 nodes.
# Processed Burst 1130 with 98 nodes.
# Processed Burst 493 with 135 nodes.
# Processed Burst 3077 with 107 nodes.
# Processed Burst 6060 with 107 nodes.
# Processed Burst 5871 with 122 nodes.
# Processed Burst 4354 with 107 nodes.
# Processed Burst 2612 with 138 nodes.
# Processed Burst 1938 with 97 nodes.
# Processed Burst 7277 with 108 nodes.
# Processed Burst 2382 with 99 nodes.
# Processed Burst 2504 with 108 nodes.
# Processed Burst 6354 with 107 nodes.
# Processed Burst 2341 with 138 nodes.
# Processed Burst 265 with 123 nodes.
# Processed Burst 1683 with 130 nodes.
# Processed Burst 7437 with 107 nodes.
# Processed Burst 1969 with 111 nodes.
# Processed Burst 7353 with 145 nodes.
# Processed Burst 6093 with 107 nodes.
# Processed Burst 5311 with 141 nodes.
# Processed Burst 3773 with 145 nodes.
# Processed Burst 5551 with 111 nodes.
# Processed Burst 416 with 133 nodes.
# Processed Burst 6466 with 108 nodes.
# Processed Burst 2679 with 107 nodes.
# Processed Burst 4202 with 111 nodes.
# Processed Burst 8192 with 107 nodes.
# Processed Burst 7886 with 107 nodes.
# Processed Burst 3155 with 111 nodes.
# Processed Burst 3831 with 138 nodes.
# Processed Burst 5304 with 107 nodes.
# Processed Burst 2336 with 107 nodes.
# Processed Burst 6487 with 107 nodes.
# Processed Burst 8695 with 108 nodes.
# Processed Burst 5681 with 111 nodes.
# Processed Burst 1334 with 145 nodes.
# Processed Burst 3434 with 97 nodes.
# Processed Burst 1758 with 145 nodes.
# Processed Burst 1735 with 141 nodes.
# Processed Burst 1681 with 98 nodes.
# Processed Burst 1197 with 134 nodes.
# Processed Burst 5094 with 145 nodes.
# Processed Burst 268 with 141 nodes.
# Processed Burst 9116 with 108 nodes.
# Processed Burst 7420 with 111 nodes.
# Processed Burst 4363 with 107 nodes.
# Processed Burst 62 with 133 nodes.
# Processed Burst 784 with 133 nodes.
# Processed Burst 87 with 129 nodes.
# Processed Burst 8044 with 108 nodes.
# Processed Burst 3176 with 108 nodes.
# Processed Burst 8120 with 140 nodes.
# Processed Burst 6089 with 141 nodes.
# Processed Burst 8369 with 107 nodes.
# Processed Burst 6824 with 108 nodes.
# Processed Burst 5211 with 141 nodes.
# Processed Burst 7046 with 145 nodes.
# Processed Burst 4482 with 107 nodes.
# Processed Burst 7734 with 141 nodes.
# Processed Burst 5922 with 108 nodes.
# Processed Burst 2493 with 108 nodes.
# Processed Burst 4860 with 107 nodes.
# Processed Burst 5995 with 108 nodes.
# Processed Burst 7739 with 122 nodes.
# Processed Burst 2592 with 111 nodes.
# Processed Burst 1622 with 134 nodes.
# Processed Burst 3339 with 99 nodes.
# Processed Burst 922 with 138 nodes.
# Processed Burst 6452 with 111 nodes.
# Processed Burst 8289 with 107 nodes.
# Processed Burst 7548 with 108 nodes.
# Processed Burst 6313 with 107 nodes.
# Processed Burst 8306 with 145 nodes.
# Processed Burst 3921 with 99 nodes.
# Processed Burst 7116 with 138 nodes.
# Processed Burst 7056 with 111 nodes.
# Processed Burst 3714 with 98 nodes.
# Processed Burst 5336 with 108 nodes.
# Processed Burst 8957 with 107 nodes.
# Processed Burst 2072 with 108 nodes.
# Processed Burst 7300 with 99 nodes.
# Processed Burst 7085 with 111 nodes.
# Processed Burst 3380 with 107 nodes.
# Processed Burst 3663 with 134 nodes.
# Processed Burst 1262 with 98 nodes.
# Processed Burst 1795 with 86 nodes.
# Processed Burst 4390 with 141 nodes.
# Processed Burst 5942 with 122 nodes.
# Processed Burst 4604 with 121 nodes.
# Processed Burst 4658 with 145 nodes.
# Processed Burst 6851 with 107 nodes.
# Processed Burst 8337 with 107 nodes.
# Processed Burst 604 with 139 nodes.
# Processed Burst 7240 with 141 nodes.
# Processed Burst 7655 with 99 nodes.
# Processed Burst 8734 with 141 nodes.
# Processed Burst 8332 with 107 nodes.
# Processed Burst 4082 with 107 nodes.
# Processed Burst 4817 with 132 nodes.
# Processed Burst 6157 with 107 nodes.
# Processed Burst 3154 with 134 nodes.
# Processed Burst 203 with 130 nodes.
# Processed Burst 8255 with 122 nodes.
# Processed Burst 630 with 137 nodes.
# Processed Burst 3874 with 99 nodes.
# Processed Burst 3720 with 108 nodes.
# Processed Burst 7047 with 107 nodes.
# Processed Burst 693 with 134 nodes.
# Processed Burst 428 with 132 nodes.
# Processed Burst 1624 with 134 nodes.
# Processed Burst 2354 with 107 nodes.
# Processed Burst 4717 with 133 nodes.
# Processed Burst 3079 with 108 nodes.
# Processed Burst 7451 with 145 nodes.
# Processed Burst 7989 with 140 nodes.
# Processed Burst 7677 with 145 nodes.
# Processed Burst 2005 with 99 nodes.
# Processed Burst 102 with 133 nodes.
# Processed Burst 4301 with 123 nodes.
# Processed Burst 6251 with 141 nodes.
# Processed Burst 6684 with 145 nodes.
# Processed Burst 215 with 125 nodes.
# Processed Burst 6994 with 111 nodes.
# Processed Burst 1039 with 108 nodes.
# Processed Burst 8224 with 107 nodes.
# Processed Burst 8960 with 122 nodes.
# Processed Burst 7318 with 141 nodes.
# Processed Burst 5184 with 145 nodes.
# Processed Burst 7206 with 134 nodes.
# Processed Burst 776 with 144 nodes.
# Processed Burst 93 with 75 nodes.
# Processed Burst 8721 with 107 nodes.
# Processed Burst 257 with 130 nodes.
# Processed Burst 6567 with 107 nodes.
# Processed Burst 6777 with 111 nodes.
# Processed Burst 1448 with 98 nodes.
# Processed Burst 1405 with 98 nodes.
# Processed Burst 8392 with 145 nodes.
# Processed Burst 4891 with 145 nodes.
# Processed Burst 7919 with 127 nodes.
# Processed Burst 283 with 145 nodes.
# Processed Burst 2869 with 123 nodes.
# Processed Burst 5955 with 108 nodes.
# Processed Burst 8029 with 107 nodes.
# Processed Burst 8609 with 107 nodes.
# Processed Burst 977 with 138 nodes.
# Processed Burst 2836 with 99 nodes.
# Processed Burst 7090 with 108 nodes.
# Processed Burst 7936 with 145 nodes.
# Processed Burst 507 with 129 nodes.
# Processed Burst 7039 with 122 nodes.
# Processed Burst 1015 with 137 nodes.
# Processed Burst 5115 with 111 nodes.
# Processed Burst 6028 with 145 nodes.
# Processed Burst 7457 with 107 nodes.
# Processed Burst 1641 with 98 nodes.
# Processed Burst 4176 with 108 nodes.
# Processed Burst 837 with 97 nodes.
# Processed Burst 5241 with 145 nodes.
# Processed Burst 5369 with 122 nodes.
# Processed Burst 1554 with 98 nodes.
# Processed Burst 2911 with 138 nodes.
# Processed Burst 4045 with 111 nodes.
# Processed Burst 6342 with 111 nodes.
# Processed Burst 524 with 132 nodes.
# Processed Burst 2664 with 145 nodes.
# Processed Burst 7889 with 107 nodes.
# Processed Burst 4296 with 111 nodes.
# Processed Burst 2863 with 133 nodes.
# Processed Burst 4165 with 129 nodes.
# Processed Burst 4355 with 99 nodes.
# Processed Burst 5483 with 108 nodes.
# Processed Burst 2633 with 107 nodes.
# Processed Burst 2373 with 108 nodes.
# Processed Burst 612 with 99 nodes.
# Processed Burst 6728 with 122 nodes.
# Processed Burst 3982 with 107 nodes.
# Processed Burst 4637 with 145 nodes.
# Processed Burst 1477 with 141 nodes.
# Processed Burst 4174 with 145 nodes.
# Processed Burst 8800 with 107 nodes.
# Processed Burst 2054 with 107 nodes.
# Processed Burst 6891 with 108 nodes.
# Processed Burst 4071 with 97 nodes.
# Processed Burst 2053 with 107 nodes.
# Processed Burst 5000 with 108 nodes.
# Processed Burst 8067 with 145 nodes.
# Processed Burst 2271 with 107 nodes.
# Processed Burst 8868 with 122 nodes.
# Processed Burst 6156 with 108 nodes.
# Processed Burst 7228 with 107 nodes.
# Processed Burst 2123 with 145 nodes.
# Processed Burst 4051 with 108 nodes.
# Processed Burst 8578 with 107 nodes.
# Processed Burst 7656 with 145 nodes.
# Processed Burst 163 with 132 nodes.
# Processed Burst 4214 with 138 nodes.
# Processed Burst 3126 with 97 nodes.
# Processed Burst 4575 with 111 nodes.
# Processed Burst 6214 with 107 nodes.
# Processed Burst 6733 with 141 nodes.
# Processed Burst 3579 with 107 nodes.
# Processed Burst 3481 with 108 nodes.
# Processed Burst 4698 with 138 nodes.
# Processed Burst 6420 with 141 nodes.
# Processed Burst 8288 with 99 nodes.
# Processed Burst 7097 with 138 nodes.
# Processed Burst 1318 with 133 nodes.
# Processed Burst 1125 with 97 nodes.
# Processed Burst 8883 with 141 nodes.
# Processed Burst 2848 with 134 nodes.
# Processed Burst 3501 with 108 nodes.
# Processed Burst 7439 with 107 nodes.
# Processed Burst 5786 with 107 nodes.
# Processed Burst 5337 with 132 nodes.
# Processed Burst 1955 with 145 nodes.
# Processed Burst 8261 with 141 nodes.
# Processed Burst 5371 with 138 nodes.
# Processed Burst 8186 with 107 nodes.
# Processed Burst 7133 with 122 nodes.
# Processed Burst 8959 with 108 nodes.
# Processed Burst 5790 with 108 nodes.
# Processed Burst 2992 with 133 nodes.
# Processed Burst 1677 with 127 nodes.
# Processed Burst 1481 with 107 nodes.
# Processed Burst 8967 with 145 nodes.
# Processed Burst 7741 with 107 nodes.
# Processed Burst 7140 with 107 nodes.
# Processed Burst 4940 with 108 nodes.
# Processed Burst 6598 with 134 nodes.
# Processed Burst 2353 with 122 nodes.
# Processed Burst 6662 with 145 nodes.
# Processed Burst 5248 with 134 nodes.
# Processed Burst 2988 with 108 nodes.
# Processed Burst 8266 with 145 nodes.
# Processed Burst 4581 with 108 nodes.
# Processed Burst 845 with 97 nodes.
# Processed Burst 8535 with 99 nodes.
# Processed Burst 1709 with 134 nodes.
# Processed Burst 997 with 122 nodes.
# Processed Burst 7496 with 141 nodes.
# Processed Burst 7617 with 108 nodes.
# Processed Burst 6617 with 145 nodes.
# Processed Burst 745 with 122 nodes.
# Processed Burst 6074 with 141 nodes.
# Processed Burst 1285 with 98 nodes.
# Processed Burst 751 with 138 nodes.
# Processed Burst 4110 with 145 nodes.
# Processed Burst 2731 with 145 nodes.
# Processed Burst 5502 with 99 nodes.
# Processed Burst 5513 with 108 nodes.
# Processed Burst 3730 with 98 nodes.
# Processed Burst 561 with 107 nodes.
# Processed Burst 6383 with 138 nodes.
# Processed Burst 7678 with 141 nodes.
# Processed Burst 7302 with 145 nodes.
# Processed Burst 816 with 123 nodes.
# Processed Burst 2017 with 108 nodes.
# Processed Burst 4888 with 145 nodes.
# Processed Burst 8424 with 107 nodes.
# Processed Burst 1651 with 102 nodes.
# Processed Burst 8620 with 108 nodes.
# Processed Burst 589 with 97 nodes.
# Processed Burst 1858 with 123 nodes.
# Processed Burst 676 with 139 nodes.
# Processed Burst 4053 with 108 nodes.
# Processed Burst 3972 with 108 nodes.
# Processed Burst 1647 with 108 nodes.
# Processed Burst 1665 with 121 nodes.
# Processed Burst 5669 with 111 nodes.
# Processed Burst 4969 with 107 nodes.
# Processed Burst 8971 with 134 nodes.
# Processed Burst 5574 with 108 nodes.
# Processed Burst 6569 with 107 nodes.
# Processed Burst 8057 with 141 nodes.
# Processed Burst 6700 with 107 nodes.
# Processed Burst 1028 with 108 nodes.
# Processed Burst 3080 with 98 nodes.
# Processed Burst 1008 with 137 nodes.
# Processed Burst 8117 with 99 nodes.
# Processed Burst 9073 with 141 nodes.
# Processed Burst 3625 with 97 nodes.
# Processed Burst 8915 with 145 nodes.
# Processed Burst 5796 with 107 nodes.
# Processed Burst 615 with 144 nodes.
# Processed Burst 2314 with 122 nodes.
# Processed Burst 3561 with 97 nodes.
# Processed Burst 761 with 123 nodes.
# Processed Burst 6575 with 108 nodes.
# Processed Burst 4195 with 138 nodes.
# Processed Burst 1216 with 98 nodes.
# Processed Burst 3956 with 138 nodes.
# Processed Burst 2693 with 108 nodes.
# Processed Burst 5013 with 141 nodes.
# Processed Burst 7992 with 141 nodes.
# Processed Burst 2458 with 107 nodes.
# Processed Burst 6793 with 107 nodes.
# Processed Burst 172 with 122 nodes.
# Processed Burst 7003 with 111 nodes.
# Processed Burst 8739 with 134 nodes.
# Processed Burst 7898 with 107 nodes.
# Processed Burst 3050 with 133 nodes.
# Processed Burst 425 with 123 nodes.
# Processed Burst 9068 with 108 nodes.
# Processed Burst 2488 with 122 nodes.
# Processed Burst 785 with 107 nodes.
# Processed Burst 770 with 123 nodes.
# Processed Burst 2064 with 141 nodes.
# Processed Burst 8909 with 107 nodes.
# Processed Burst 8928 with 145 nodes.
# Processed Burst 8398 with 145 nodes.
# Processed Burst 8651 with 141 nodes.
# Processed Burst 688 with 98 nodes.
# Processed Burst 7843 with 107 nodes.
# Processed Burst 8564 with 141 nodes.
# Processed Burst 1640 with 140 nodes.
# Processed Burst 4704 with 132 nodes.
# Processed Burst 6640 with 108 nodes.
# Processed Burst 2862 with 107 nodes.
# Processed Burst 2638 with 97 nodes.
# Processed Burst 5306 with 107 nodes.
# Processed Burst 5900 with 141 nodes.
# Processed Burst 618 with 138 nodes.
# Processed Burst 9022 with 107 nodes.
# Processed Burst 865 with 99 nodes.
# Processed Burst 8644 with 141 nodes.
# Processed Burst 8492 with 141 nodes.
# Processed Burst 8545 with 107 nodes.
# Processed Burst 1164 with 138 nodes.
# Processed Burst 3992 with 111 nodes.
# Processed Burst 7982 with 107 nodes.
# Processed Burst 37 with 127 nodes.
# Processed Burst 451 with 131 nodes.
# Processed Burst 1790 with 145 nodes.
# Processed Burst 1987 with 141 nodes.
# Processed Burst 8513 with 145 nodes.
# Processed Burst 6883 with 141 nodes.
# Processed Burst 6595 with 141 nodes.
# Processed Burst 5732 with 145 nodes.
# Processed Burst 1357 with 141 nodes.
# Processed Burst 6946 with 145 nodes.
# Processed Burst 8274 with 145 nodes.
# Processed Burst 2556 with 138 nodes.
# Processed Burst 4411 with 138 nodes.
# Processed Burst 1900 with 98 nodes.
# Processed Burst 5274 with 145 nodes.
# Processed Burst 6608 with 111 nodes.
# Processed Burst 2410 with 108 nodes.
# Processed Burst 8024 with 99 nodes.
# Processed Burst 7618 with 145 nodes.
# Processed Burst 1252 with 123 nodes.
# Processed Burst 7770 with 138 nodes.
# Processed Burst 6476 with 107 nodes.
# Processed Burst 6403 with 138 nodes.
# Processed Burst 1188 with 99 nodes.
# Processed Burst 244 with 145 nodes.
# Processed Burst 6521 with 145 nodes.
# Processed Burst 5221 with 134 nodes.
# Processed Burst 2169 with 107 nodes.
# Processed Burst 3607 with 108 nodes.
# Processed Burst 8683 with 141 nodes.
# Processed Burst 8780 with 108 nodes.
# Processed Burst 1437 with 139 nodes.
# Processed Burst 6695 with 145 nodes.
# Processed Burst 8782 with 99 nodes.
# Processed Burst 3483 with 145 nodes.
# Processed Burst 5462 with 145 nodes.
# Processed Burst 1093 with 99 nodes.
# Processed Burst 6165 with 108 nodes.
# Processed Burst 3024 with 141 nodes.
# Processed Burst 1455 with 98 nodes.
# Processed Burst 8743 with 122 nodes.
# Processed Burst 1872 with 91 nodes.
# Processed Burst 6726 with 108 nodes.
# Processed Burst 6609 with 111 nodes.
# Processed Burst 2047 with 107 nodes.
# Processed Burst 2875 with 145 nodes.
# Processed Burst 853 with 141 nodes.
# Processed Burst 948 with 97 nodes.
# Processed Burst 2508 with 98 nodes.
# Processed Burst 1150 with 130 nodes.
# Processed Burst 3652 with 130 nodes.
# Processed Burst 5161 with 107 nodes.
# Processed Burst 264 with 123 nodes.
# Processed Burst 1414 with 99 nodes.
# Processed Burst 1531 with 137 nodes.
# Processed Burst 3128 with 132 nodes.
# Processed Burst 6533 with 111 nodes.
# Processed Burst 5178 with 107 nodes.
# Processed Burst 7646 with 108 nodes.
# Processed Burst 3257 with 141 nodes.
# Processed Burst 4474 with 108 nodes.
# Processed Burst 166 with 96 nodes.
# Processed Burst 760 with 123 nodes.
# Processed Burst 613 with 111 nodes.
# Processed Burst 8720 with 107 nodes.
# Processed Burst 6460 with 111 nodes.
# Processed Burst 3409 with 122 nodes.
# Processed Burst 7210 with 134 nodes.
# Processed Burst 7105 with 108 nodes.
# Processed Burst 7377 with 134 nodes.
# Processed Burst 749 with 132 nodes.
# Processed Burst 3499 with 138 nodes.
# Processed Burst 7403 with 108 nodes.
# Processed Burst 8786 with 107 nodes.
# Processed Burst 4671 with 141 nodes.
# Processed Burst 1654 with 144 nodes.
# Processed Burst 6185 with 141 nodes.
# Processed Burst 3365 with 99 nodes.
# Processed Burst 9104 with 111 nodes.
# Processed Burst 2451 with 111 nodes.
# Processed Burst 5050 with 141 nodes.
# Processed Burst 142 with 133 nodes.
# Processed Burst 7477 with 145 nodes.
# Processed Burst 454 with 121 nodes.
# Processed Burst 3692 with 133 nodes.
# Processed Burst 2150 with 145 nodes.
# Processed Burst 8450 with 111 nodes.
# Processed Burst 7043 with 107 nodes.
# Processed Burst 8221 with 133 nodes.
# Processed Burst 178 with 127 nodes.
# Processed Burst 3337 with 138 nodes.
# Processed Burst 5979 with 141 nodes.
# Processed Burst 3609 with 97 nodes.
# Processed Burst 6528 with 138 nodes.
# Processed Burst 5523 with 107 nodes.
# Processed Burst 4043 with 134 nodes.
# Processed Burst 7540 with 107 nodes.
# Processed Burst 6681 with 99 nodes.
# Processed Burst 5905 with 107 nodes.
# Processed Burst 3508 with 141 nodes.
# Processed Burst 1614 with 98 nodes.
# Processed Burst 4948 with 145 nodes.
# Processed Burst 1265 with 107 nodes.
# Processed Burst 8352 with 107 nodes.
# Processed Burst 4438 with 99 nodes.
# Processed Burst 324 with 132 nodes.
# Processed Burst 827 with 133 nodes.
# Processed Burst 7419 with 145 nodes.
# Processed Burst 2703 with 138 nodes.
# Processed Burst 7747 with 141 nodes.
# Processed Burst 2598 with 107 nodes.
# Processed Burst 6941 with 108 nodes.
# Processed Burst 1237 with 134 nodes.
# Processed Burst 393 with 99 nodes.
# Processed Burst 754 with 108 nodes.
# Processed Burst 156 with 123 nodes.
# Processed Burst 7271 with 141 nodes.
# Processed Burst 7814 with 141 nodes.
# Processed Burst 3301 with 122 nodes.
# Processed Burst 3596 with 111 nodes.
# Processed Burst 699 with 145 nodes.
# Processed Burst 2535 with 145 nodes.
# Processed Burst 3817 with 99 nodes.
# Processed Burst 5217 with 111 nodes.
# Processed Burst 5039 with 108 nodes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 97
#      94 edge_index = from_networkx(G).edge_index
#      96 # collect per-node pre-burst and non-burst spike-features
# ---> 97 pre_dict = get_pre_burst_spikes_and_features(h5_path, nodes, burst_tick, k=20)
#      98 non_dict = get_non_burst_spikes_and_features(h5_path, nodes, burst_tick, k=20, gap=100)
#     100 # build feature matrices in node-order
#
# Cell In[6], line 22, in get_pre_burst_spikes_and_features(h5_path, node_ids, burst_tick, k)
#      20     feats = get_spike_features(arr)
#      21 else:
# ---> 22     spikes = np.sort(h5[ds][()]).astype(float)
#      23     idx0 = np.searchsorted(spikes, burst_tick)
#      24     last_k = spikes[max(0, idx0-k):idx0]
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /DATA/hdhanu/lib/python3.12/site-packages/h5py/_hl/dataset.py:758, in Dataset.__getitem__(self, args, new_dtype)
#     756 if self._fast_read_ok and (new_dtype is None):
#     757     try:
# --> 758         return self._fast_reader.read(args)
#     759     except TypeError:
#     760         pass  # Fall back to Python read pathway below
#
# KeyboardInterrupt:

# %%
import torch

# 1) Load your processed graphs (turn off weights_only safety)
data_list = torch.load(
    '/DATA/hdhanu/GNN/Manual_check/processed_data.pt',
    weights_only=False
)

total_graphs     = len(data_list)
graphs_with_nan  = 0
total_nan_counts = 0

# 2) Iterate through each graph’s node‐features
for idx, data in enumerate(data_list):
    # data.x is [num_nodes, num_features]
    nan_mask = torch.isnan(data.x)
    n_nans   = nan_mask.sum().item()
    if n_nans > 0:
        graphs_with_nan  += 1
        total_nan_counts += n_nans
        print(f"Graph {idx} has {n_nans} NaNs")

# 3) Summary
print(f"\nFound NaNs in {graphs_with_nan}/{total_graphs} graphs, " 
      f"total NaN entries: {total_nan_counts}")
# Out:
# Graph 4761 has 21 NaNs
# Graph 5323 has 2 NaNs
# Graph 6399 has 1 NaNs
# Graph 12820 has 118 NaNs
# Graph 14663 has 22 NaNs
# Graph 18283 has 2 NaNs
#
# Found NaNs in 6/18316 graphs, total NaN entries: 166

# %%
clean_list   = []
dropped_bursts = 0

# data_list was built as [pre_0, non_0, pre_1, non_1, …]
for i in range(0, len(data_list), 2):
    pre, non = data_list[i], data_list[i+1]
    # if either graph has NaNs, drop the whole pair
    if torch.isnan(pre.x).any() or torch.isnan(non.x).any():
        dropped_bursts += 1
        continue
    clean_list.extend([pre, non])

print(f"Dropped {dropped_bursts} bursts ({dropped_bursts*2} graphs) with NaNs")
data_list = clean_list
torch.save(data_list, '/DATA/hdhanu/GNN/Manual_check/clean_processed_data.pt')
# Out:
# Dropped 6 bursts (12 graphs) with NaNs

# %%
# 2) Stack all node‐features into F
#    Each data.x is [n_nodes_i, n_feats]
from sklearn.discriminant_analysis import StandardScaler
import numpy as np

F = np.vstack([ data.x.numpy() for data in data_list ])  # shape [total_nodes, n_feats]

# 3) Fit the StandardScaler
scaler = StandardScaler()
scaler.fit(F)

# 4) Transform each graph’s x in place
for data in data_list:
    X = data.x.numpy()           # [n_nodes, n_feats]
    X_scaled = scaler.transform(X)
    data.x = torch.tensor(X_scaled, dtype=torch.float)

# 5) Save the scaled dataset and the scaler object
torch.save(data_list, '/DATA/hdhanu/GNN/Manual_check/clean_scaled_processed_data.pt')
